# %% [markdown]
# <a href="https://colab.research.google.com/github/rakeshrana87/Angular_weeklyReport_Example/blob/master/gnn_conflict_mgmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GNN that predicts how a paramter change on one cell cascades through the network topology to affect KPIs on all cells.

# %% [markdown]
# Data Generation
# Generate 2000 training samples using the network simulator.  Each sample :  pick random cell + param -> record KPIs before/after -> delta is the label

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import MessagePassing, GCNConv
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# Add project root to path
ROOT = Path('.').resolve().parent
sys.path.insert(0, str(ROOT))

from src.simulator import NetworkSimulator
from src.dataset import generate_training_data
from src.config import(KPI_NAME, PARAM_NAMES, NUM_KPIS, NUM_PARAMS, GNN_INPUT_DIM, GNN_HIDDEN_DIM, GNN_NUM_LAYERS, GNN_OUTPUT_DIM, BATCH_SIZE, EPOCHS, LEARNING_RATE, WEIGHT_DECAY, MC_DROPOUT_RUNS, MC_DROPOUT_RATE, TRAIN_SAMPLES)
device = torch.device('cude' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')

DATA_DIR = ROOT / 'data'
MODEL_DIR = ROOT / 'models'
FIG_DIR = ROOT / 'firgures'
for d in [DATA_DIR, MODEL_DIR, FIG_DIR]:
    d.mkdir(exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_11592/1211100506.py in <cell line: 0>()
#       7 import torch.nn as nn
#       8 import torch.nn.functional as F
# ----> 9 from torch_geometric.data import Data
#      10 from torch_geometric.loader import DataLoader
#      11 from torch_geometric.nn import MessagePassing, GCNConv
#
# ModuleNotFoundError: No module named 'torch_geometric'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# GENERATE TRAINING DATA
sim = NetworkSimulator()
CELL_IDS = list(sim.cells.keys())
NUM_CELLS = len(CELL_IDS)
print(f'Topology: {NUM_CELLS} cells, {}')
